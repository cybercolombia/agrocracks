# %%
import geopandas as gpd
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon
from matplotlib.colors import ListedColormap

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
suelos_2026= pd.read_csv('/content/drive/MyDrive/eco2026/Suelos__Colombia_2026.csv')
suelos_2026.info()
# Out:
# /tmp/ipykernel_2039/2073348628.py:1: DtypeWarning: Columns (11,12,13,14,17,18,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   suelos_2026= pd.read_csv('/content/drive/MyDrive/eco2026/Suelos__Colombia_2026.csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92738 entries, 0 to 92737
# Data columns (total 32 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Secuencial                          92738 non-null  object
#  1   Fecha de Análisis                   92738 non-null  object
#  2   Departamento                        92738 non-null  object
#  3   Municipio                           92736 non-null  object
#  4   Cultivo                             92738 non-null  object
#  5   Estado                              92738 non-null  object
#  6   Tiempo de establecimiento           92738 non-null  object
# ...

# %%
suelos_2026.head()
# Out:
#   Secuencial Fecha de Análisis Departamento             Municipio     Cultivo  \
# 0          1         7/01/2014       NARIÑO  SAN ANDRÉS DE TUMACO   No Indica
# 1          2        21/08/2014        HUILA           SANTA MARÍA  Granadilla
# 2          3        22/08/2014    ANTIOQUIA              LIBORINA        Café
# 3          4        22/08/2014    ANTIOQUIA              LIBORINA    Maracuyá
# 4          5        22/08/2014    ANTIOQUIA              LIBORINA        Café
#
#            Estado Tiempo de establecimiento Topografia       Drenaje  \
# 0       No indica                 No indica  No indica     No indica
# 1     Establecido             De 1 a 5 años  Pendiente  Buen drenaje
# 2  Por establecer                 No indica  Pendiente   Mal drenaje
# 3  Por establecer                 No indica   Ondulado   Mal drenaje
# 4  Por establecer                 No indica   Ondulado   Mal drenaje
#
#        Riego  ... Conductividad electrica Hierro disponible olsen  \
# ...

# %%
filtered_suelos = suelos_2026[suelos_2026['Cultivo'] != 'No Indica']
departamentos_cultivo_counts = filtered_suelos['Departamento'].value_counts().reset_index()
departamentos_cultivo_counts.columns = ['Departamento', 'Numero de Registros']
display(departamentos_cultivo_counts.head(10))
# Out:
#          Departamento  Numero de Registros
# 0        CUNDINAMARCA                13280
# 1     VALLE DEL CAUCA                 8904
# 2           ANTIOQUIA                 7633
# 3                META                 6635
# 4              NARIÑO                 5737
# 5              BOYACÁ                 4765
# 6           SANTANDER                 4473
# 7  NORTE DE SANTANDER                 3785
# 8            PUTUMAYO                 3073
# 9              TOLIMA                 2737
